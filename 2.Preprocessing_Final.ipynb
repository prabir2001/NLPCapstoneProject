# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# used to supress display of warnings
import warnings

# os is used to provide a way of using operating system dependent functionality
# We use it for setting working folder
import os

# Pandas is used for data manipulation and analysis
import pandas as pd 

# Numpy is used for large, multi-dimensional arrays and matrices, along with mathematical operators on these arrays
import numpy as np

from google.colab import files
import time

# Matplotlib is a data visualization library for 2D plots of arrays, built on NumPy arrays 
# and designed to work with the broader SciPy stack
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import pyplot

# Seaborn is based on matplotlib, which aids in drawing attractive and informative statistical graphics.
import seaborn as sns
import tensorflow 
print(tensorflow.__version__)
# Out:
# 2.5.0

# %%
# suppress display of warnings
warnings.filterwarnings('ignore')

# display all dataframe columns
pd.options.display.max_columns = None

# to set the limit to 3 decimals
pd.options.display.float_format = '{:.7f}'.format

# display all dataframe rows
pd.options.display.max_rows = None

# %%
#Read the data scraped
filepath = "/content/drive/MyDrive/AI-ML/Data/Ent_Articles_combined_withAuthor12June r2.csv"
df = pd.read_csv(filepath)
df.head()
# Out:
#    Unnamed: 0                                  Article URL  \
# 0   0.0000000  https://www.entrepreneur.com/article/370874
# 1   1.0000000  https://www.entrepreneur.com/article/372254
# 2   2.0000000  https://www.entrepreneur.com/article/368356
# 3   3.0000000  https://www.entrepreneur.com/article/373825
# 4   4.0000000  https://www.entrepreneur.com/article/372679
#
#                                             Headline  \
# 0  \n\t\t\t\tIs Launching a New Brand the Right M...
# 1  \n\t\t\t\t3 Reasons Simple Isn't Always Better...
# 2  \n\t\t\t\tFrom Idea to Revenue: A Six-Step For...
# 3  \n\t\t\t\tAvoid This Common Mistake When Writi...
# 4   \n\t\t\t\tIs it Time to Say RIP to RFPs?\n\t\t\t
#
#                                         Article Text            Sub Domain  \
# 0  \n\n\n\t\t\t\t\t\t\t\tJune\n\t\t\t\t\t\t\t\t10...              Branding
# 1  \n\n\n\t\t\t\t\t\t\t\tJune\n\t\t\t\t\t\t\t\t10...              Branding
# 2  \n\n\n\t\t\t\t\t\t\t\tJune\n\t\t\t\t\t\t\t\t10...  Launching a Business
# 3  \n\n\n\t\t\t\t\t\t\t\tJune\n\t\t\t\t\t\t\t\t10...        Writing a Book
# 4  \n\n\n\t\t\t\t\t\t\t\tJune\n\t\t\t\t\t\t\t\t9,...         Entrepreneurs
#
#       Domain             Author
# 0  Marketing    Melissa Packham
# 1  Marketing      Zaheer Dodhia
# 2  Marketing  Jessica O'Connell
# 3  Marketing   R. Paulo Delgado
# 4  Marketing     Heather Ripley

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32108 entries, 0 to 32107
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    30628 non-null  float64
#  1   Article URL   30060 non-null  object
#  2   Headline      32108 non-null  object
#  3   Article Text  32108 non-null  object
#  4   Sub Domain    30628 non-null  object
#  5   Domain        32108 non-null  object
#  6   Author        32108 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 1.7+ MB

# %%
df.shape
# Out:
# (32108, 7)

# %%
#check any na
df.isna().sum()
# Out:
# Unnamed: 0      1480
# Article URL     2048
# Headline           0
# Article Text       0
# Sub Domain      1480
# Domain             0
# Author             0
# dtype: int64

# %%
#NO URL available
df[df['Article URL'].isna()]
# Out:
#         Unnamed: 0 Article URL  \
# 19694          nan         NaN
# 30061 2073.0000000         NaN
# 30062 2074.0000000         NaN
# 30063 2082.0000000         NaN
# 30064 2083.0000000         NaN
# 30065 2084.0000000         NaN
# 30066 2085.0000000         NaN
# 30067 2086.0000000         NaN
# 30068 2087.0000000         NaN
# 30069 2088.0000000         NaN
# 30070 2089.0000000         NaN
# 30071 2090.0000000         NaN
# 30072 2091.0000000         NaN
# 30073 2093.0000000         NaN
# 30074 2100.0000000         NaN
# 30075 2101.0000000         NaN
# 30076 2102.0000000         NaN
# 30077 2103.0000000         NaN
# 30078 2104.0000000         NaN
# 30079 2105.0000000         NaN
# 30080 2106.0000000         NaN
# 30081 2107.0000000         NaN
# 30082 2108.0000000         NaN
# 30083 2109.0000000         NaN
# 30084 2110.0000000         NaN
# 30085 2111.0000000         NaN
# 30086 2118.0000000         NaN
# 30087 2119.0000000         NaN
# 30088 2120.0000000         NaN
# 30089 2121.0000000         NaN
# 30090 2122.0000000         NaN
# 30091 2123.0000000         NaN
# 30092 2124.0000000         NaN
# 30093 2125.0000000         NaN
# 30094 2126.0000000         NaN
# 30095 2127.0000000         NaN
# 30096 2128.0000000         NaN
# 30097 2129.0000000         NaN
# 30098 2136.0000000         NaN
# 30099 2137.0000000         NaN
# 30100 2138.0000000         NaN
# 30101 2139.0000000         NaN
# 30102 2141.0000000         NaN
# 30103 2142.0000000         NaN
# 30104 2143.0000000         NaN
# 30105 2144.0000000         NaN
# 30106 2147.0000000         NaN
# 30107 2154.0000000         NaN
# 30108 2155.0000000         NaN
# 30109 2156.0000000         NaN
# 30110 2157.0000000         NaN
# 30111 2158.0000000         NaN
# 30112 2159.0000000         NaN
# 30113 2160.0000000         NaN
# 30114 2161.0000000         NaN
# 30115 2162.0000000         NaN
# 30116 2163.0000000         NaN
# 30117 2164.0000000         NaN
# 30118 2165.0000000         NaN
# 30119 2172.0000000         NaN
# 30120 2173.0000000         NaN
# 30121 2174.0000000         NaN
# 30122 2175.0000000         NaN
# 30123 2176.0000000         NaN
# 30124 2178.0000000         NaN
# 30125 2179.0000000         NaN
# 30126 2180.0000000         NaN
# 30127 2181.0000000         NaN
# 30128 2190.0000000         NaN
# 30129 2191.0000000         NaN
# 30130 2192.0000000         NaN
# 30131 2193.0000000         NaN
# 30132 2194.0000000         NaN
# 30133 2195.0000000         NaN
# 30134 2196.0000000         NaN
# 30135 2197.0000000         NaN
# 30136 2198.0000000         NaN
# 30137 2199.0000000         NaN
# 30138 2200.0000000         NaN
# 30139 2201.0000000         NaN
# 30140 2208.0000000         NaN
# 30141 2209.0000000         NaN
# 30142 2210.0000000         NaN
# 30143 2211.0000000         NaN
# 30144 2212.0000000         NaN
# 30145 2213.0000000         NaN
# 30146 2215.0000000         NaN
# 30147 2216.0000000         NaN
# 30148 2217.0000000         NaN
# 30149 2218.0000000         NaN
# 30150 2219.0000000         NaN
# 30151 2227.0000000         NaN
# 30152 2228.0000000         NaN
# 30153 2229.0000000         NaN
# 30154 2230.0000000         NaN
# 30155 2231.0000000         NaN
# 30156 2232.0000000         NaN
# 30157 2233.0000000         NaN
# 30158 2234.0000000         NaN
# 30159 2235.0000000         NaN
# 30160 2236.0000000         NaN
# 30161 2237.0000000         NaN
# 30162 2244.0000000         NaN
# 30163 2245.0000000         NaN
# 30164 2246.0000000         NaN
# 30165 2247.0000000         NaN
# 30166 2249.0000000         NaN
# 30167 2250.0000000         NaN
# 30168 2251.0000000         NaN
# 30169 2252.0000000         NaN
# 30170 2253.0000000         NaN
# 30171 2254.0000000         NaN
# 30172 2255.0000000         NaN
# 30173 2262.0000000         NaN
# 30174 2263.0000000         NaN
# 30175 2264.0000000         NaN
# 30176 2265.0000000         NaN
# 30177 2266.0000000         NaN
# 30178 2267.0000000         NaN
# 30179 2268.0000000         NaN
# 30180 2269.0000000         NaN
# 30181 2270.0000000         NaN
# 30182 2271.0000000         NaN
# 30183 2272.0000000         NaN
# 30184 2273.0000000         NaN
# 30185 2280.0000000         NaN
# 30186 2281.0000000         NaN
# 30187 2283.0000000         NaN
# 30188 2284.0000000         NaN
# 30189 2285.0000000         NaN
# 30190 2286.0000000         NaN
# 30191 2287.0000000         NaN
# 30192 2288.0000000         NaN
# 30193 2289.0000000         NaN
# 30194 2290.0000000         NaN
# 30195 2291.0000000         NaN
# 30196 2298.0000000         NaN
# 30197 2300.0000000         NaN
# 30198 2301.0000000         NaN
# 30199 2302.0000000         NaN
# 30200 2303.0000000         NaN
# 30201 2304.0000000         NaN
# 30202 2305.0000000         NaN
# 30203 2306.0000000         NaN
# 30204 2307.0000000         NaN
# 30205 2308.0000000         NaN
# 30206 2309.0000000         NaN
# 30207 2316.0000000         NaN
# 30208 2317.0000000         NaN
# 30209 2318.0000000         NaN
# 30210 2319.0000000         NaN
# 30211 2321.0000000         NaN
# 30212 2322.0000000         NaN
# 30213 2323.0000000         NaN
# 30214 2324.0000000         NaN
# 30215 2325.0000000         NaN
# 30216 2327.0000000         NaN
# 30217 2334.0000000         NaN
# 30218 2335.0000000         NaN
# 30219 2336.0000000         NaN
# 30220 2337.0000000         NaN
# 30221 2338.0000000         NaN
# 30222 2339.0000000         NaN
# 30223 2340.0000000         NaN
# 30224 2342.0000000         NaN
# 30225 2343.0000000         NaN
# 30226 2344.0000000         NaN
# 30227 2345.0000000         NaN
# 30228 2352.0000000         NaN
# 30229 2353.0000000         NaN
# 30230 2354.0000000         NaN
# 30231 2355.0000000         NaN
# 30232 2356.0000000         NaN
# 30233 2357.0000000         NaN
# 30234 2358.0000000         NaN
# 30235 2359.0000000         NaN
# 30236 2360.0000000         NaN
# 30237 2361.0000000         NaN
# 30238 2362.0000000         NaN
# 30239 2363.0000000         NaN
# 30240 2370.0000000         NaN
# 30241 2371.0000000         NaN
# 30242 2372.0000000         NaN
# 30243 2373.0000000         NaN
# 30244 2374.0000000         NaN
# 30245 2375.0000000         NaN
# 30246 2376.0000000         NaN
# 30247 2377.0000000         NaN
# 30248 2378.0000000         NaN
# 30249 2379.0000000         NaN
# 30250 2380.0000000         NaN
# 30251 2381.0000000         NaN
# 30252 2388.0000000         NaN
# 30253 2389.0000000         NaN
# 30254 2390.0000000         NaN
# 30255 2391.0000000         NaN
# 30256 2392.0000000         NaN
# 30257 2393.0000000         NaN
# 30258 2394.0000000         NaN
# 30259 2395.0000000         NaN
# 30260 2396.0000000         NaN
# 30261 2397.0000000         NaN
# 30262 2398.0000000         NaN
# 30263 2399.0000000         NaN
# 30264 2406.0000000         NaN
# 30265 2407.0000000         NaN
# 30266 2408.0000000         NaN
# 30267 2409.0000000         NaN
# 30268 2410.0000000         NaN
# 30269 2411.0000000         NaN
# 30270 2412.0000000         NaN
# 30271 2413.0000000         NaN
# 30272 2414.0000000         NaN
# 30273 2415.0000000         NaN
# 30274 2417.0000000         NaN
# 30275 2424.0000000         NaN
# 30276 2425.0000000         NaN
# 30277 2426.0000000         NaN
# 30278 2427.0000000         NaN
# 30279 2428.0000000         NaN
# 30280 2429.0000000         NaN
# 30281 2430.0000000         NaN
# 30282 2431.0000000         NaN
# 30283 2432.0000000         NaN
# 30284 2433.0000000         NaN
# 30285 2434.0000000         NaN
# 30286 2435.0000000         NaN
# 30287 2442.0000000         NaN
# 30288 2443.0000000         NaN
# 30289 2444.0000000         NaN
# 30290 2445.0000000         NaN
# 30291 2446.0000000         NaN
# 30292 2447.0000000         NaN
# 30293 2448.0000000         NaN
# 30294 2449.0000000         NaN
# 30295 2451.0000000         NaN
# 30296 2452.0000000         NaN
# 30297 2453.0000000         NaN
# 30298 2460.0000000         NaN
# 30299 2461.0000000         NaN
# 30300 2462.0000000         NaN
# 30301 2463.0000000         NaN
# 30302 2464.0000000         NaN
# 30303 2465.0000000         NaN
# 30304 2466.0000000         NaN
# 30305 2467.0000000         NaN
# 30306 2468.0000000         NaN
# 30307 2469.0000000         NaN
# 30308 2470.0000000         NaN
# 30309 2471.0000000         NaN
# 30310 2478.0000000         NaN
# 30311 2479.0000000         NaN
# 30312 2480.0000000         NaN
# 30313 2481.0000000         NaN
# 30314 2482.0000000         NaN
# 30315 2483.0000000         NaN
# 30316 2484.0000000         NaN
# 30317 2485.0000000         NaN
# 30318 2486.0000000         NaN
# 30319 2487.0000000         NaN
# 30320 2488.0000000         NaN
# 30321 2489.0000000         NaN
# 30322 2496.0000000         NaN
# 30323 2497.0000000         NaN
# 30324 2498.0000000         NaN
# 30325 2499.0000000         NaN
# 30326 2500.0000000         NaN
# 30327 2501.0000000         NaN
# 30328 2502.0000000         NaN
# 30329 2503.0000000         NaN
# 30330 2504.0000000         NaN
# 30331 2505.0000000         NaN
# 30332 2506.0000000         NaN
# 30333 2514.0000000         NaN
# 30334 2515.0000000         NaN
# 30335 2516.0000000         NaN
# 30336 2517.0000000         NaN
# 30337 2518.0000000         NaN
# 30338 2519.0000000         NaN
# 30339 2520.0000000         NaN
# 30340 2521.0000000         NaN
# 30341 2522.0000000         NaN
# 30342 2523.0000000         NaN
# 30343 2525.0000000         NaN
# 30344 2532.0000000         NaN
# 30345 2533.0000000         NaN
# 30346 2534.0000000         NaN
# 30347 2535.0000000         NaN
# 30348 2536.0000000         NaN
# 30349 2537.0000000         NaN
# 30350 2538.0000000         NaN
# 30351 2539.0000000         NaN
# 30352 2540.0000000         NaN
# 30353 2541.0000000         NaN
# 30354 2542.0000000         NaN
# 30355 2543.0000000         NaN
# 30356 2550.0000000         NaN
# 30357 2551.0000000         NaN
# 30358 2552.0000000         NaN
# 30359 2553.0000000         NaN
# 30360 2554.0000000         NaN
# 30361 2555.0000000         NaN
# 30362 2556.0000000         NaN
# 30363 2557.0000000         NaN
# 30364 2558.0000000         NaN
# 30365 2559.0000000         NaN
# 30366 2560.0000000         NaN
# 30367 2561.0000000         NaN
# 30368 2568.0000000         NaN
# 30369 2569.0000000         NaN
# 30370 2570.0000000         NaN
# 30371 2571.0000000         NaN
# 30372 2573.0000000         NaN
# 30373 2574.0000000         NaN
# 30374 2575.0000000         NaN
# 30375 2576.0000000         NaN
# 30376 2577.0000000         NaN
# 30377 2578.0000000         NaN
# 30378 2579.0000000         NaN
# 30379 2586.0000000         NaN
# 30380 2587.0000000         NaN
# 30381 2588.0000000         NaN
# 30382 2589.0000000         NaN
# 30383 2590.0000000         NaN
# 30384 2591.0000000         NaN
# 30385 2592.0000000         NaN
# 30386 2593.0000000         NaN
# 30387 2594.0000000         NaN
# 30388 2596.0000000         NaN
# 30389 2597.0000000         NaN
# 30390 2604.0000000         NaN
# 30391 2605.0000000         NaN
# 30392 2606.0000000         NaN
# 30393 2607.0000000         NaN
# 30394 2608.0000000         NaN
# 30395 2609.0000000         NaN
# 30396 2610.0000000         NaN
# 30397 2611.0000000         NaN
# 30398 2612.0000000         NaN
# 30399 2613.0000000         NaN
# 30400 2614.0000000         NaN
# 30401 2615.0000000         NaN
# 30402 2622.0000000         NaN
# 30403 2623.0000000         NaN
# 30404 2624.0000000         NaN
# 30405 2625.0000000         NaN
# 30406 2626.0000000         NaN
# 30407 2627.0000000         NaN
# 30408 2628.0000000         NaN
# 30409 2629.0000000         NaN
# 30410 2630.0000000         NaN
# 30411 2631.0000000         NaN
# 30412 2632.0000000         NaN
# 30413 2633.0000000         NaN
# 30414 2640.0000000         NaN
# 30415 2641.0000000         NaN
# 30416 2642.0000000         NaN
# 30417 2643.0000000         NaN
# 30418 2646.0000000         NaN
# 30419 2647.0000000         NaN
# 30420 2648.0000000         NaN
# 30421 2649.0000000         NaN
# 30422 2650.0000000         NaN
# 30423 2658.0000000         NaN
# 30424 2659.0000000         NaN
# 30425 2660.0000000         NaN
# 30426 2662.0000000         NaN
# 30427 2663.0000000         NaN
# 30428 2664.0000000         NaN
# 30429 2665.0000000         NaN
# 30430 2666.0000000         NaN
# 30431 2667.0000000         NaN
# 30432 2668.0000000         NaN
# 30433 2669.0000000         NaN
# 30434 2676.0000000         NaN
# 30435 2677.0000000         NaN
# 30436 2678.0000000         NaN
# 30437 2679.0000000         NaN
# 30438 2680.0000000         NaN
# 30439 2681.0000000         NaN
# 30440 2682.0000000         NaN
# 30441 2683.0000000         NaN
# 30442 2684.0000000         NaN
# 30443 2685.0000000         NaN
# 30444 2686.0000000         NaN
# 30445 2687.0000000         NaN
# 30446 2694.0000000         NaN
# 30447 2695.0000000         NaN
# 30448 2696.0000000         NaN
# 30449 2697.0000000         NaN
# 30450 2698.0000000         NaN
# 30451 2699.0000000         NaN
# 30452 2700.0000000         NaN
# 30453 2701.0000000         NaN
# 30454 2702.0000000         NaN
# 30455 2703.0000000         NaN
# 30456 2704.0000000         NaN
# 30457 2705.0000000         NaN
# 30458 2712.0000000         NaN
# 30459 2713.0000000         NaN
# 30460 2714.0000000         NaN
# 30461 2715.0000000         NaN
# 30462 2716.0000000         NaN
# 30463 2717.0000000         NaN
# 30464 2718.0000000         NaN
# 30465 2719.0000000         NaN
# 30466 2720.0000000         NaN
# 30467 2721.0000000         NaN
# 30468 2722.0000000         NaN
# 30469 2723.0000000         NaN
# 30470 2730.0000000         NaN
# 30471 2732.0000000         NaN
# 30472 2733.0000000         NaN
# 30473 2734.0000000         NaN
# 30474 2735.0000000         NaN
# 30475 2736.0000000         NaN
# 30476 2738.0000000         NaN
# 30477 2739.0000000         NaN
# 30478 2740.0000000         NaN
# 30479 2741.0000000         NaN
# 30480 2748.0000000         NaN
# 30481 2749.0000000         NaN
# 30482 2750.0000000         NaN
# 30483 2751.0000000         NaN
# 30484 2752.0000000         NaN
# 30485 2753.0000000         NaN
# 30486 2754.0000000         NaN
# 30487 2755.0000000         NaN
# 30488 2756.0000000         NaN
# 30489 2757.0000000         NaN
# 30490 2758.0000000         NaN
# 30491 2759.0000000         NaN
# 30492 2766.0000000         NaN
# 30493 2767.0000000         NaN
# 30494 2768.0000000         NaN
# 30495 2769.0000000         NaN
# 30496 2770.0000000         NaN
# 30497 2771.0000000         NaN
# 30498 2772.0000000         NaN
# 30499 2773.0000000         NaN
# 30500 2774.0000000         NaN
# 30501 2775.0000000         NaN
# 30502 2776.0000000         NaN
# 30503 2784.0000000         NaN
# 30504 2786.0000000         NaN
# 30505 2787.0000000         NaN
# 30506 2788.0000000         NaN
# 30507 2789.0000000         NaN
# 30508 2790.0000000         NaN
# 30509 2792.0000000         NaN
# 30510 2793.0000000         NaN
# 30511 2795.0000000         NaN
# 30512 2802.0000000         NaN
# 30513 2804.0000000         NaN
# 30514 2805.0000000         NaN
# 30515 2806.0000000         NaN
# 30516 2807.0000000         NaN
# 30517 2808.0000000         NaN
# 30518 2809.0000000         NaN
# 30519 2810.0000000         NaN
# 30520 2811.0000000         NaN
# 30521 2812.0000000         NaN
# 30522 2813.0000000         NaN
# 30523 2820.0000000         NaN
# 30524 2821.0000000         NaN
# 30525 2822.0000000         NaN
# 30526 2823.0000000         NaN
# 30527 2825.0000000         NaN
# 30528 2826.0000000         NaN
# 30529 2827.0000000         NaN
# 30530 2829.0000000         NaN
# 30531 2831.0000000         NaN
# 30532 2838.0000000         NaN
# 30533 2839.0000000         NaN
# 30534 2840.0000000         NaN
# 30535 2841.0000000         NaN
# 30536 2842.0000000         NaN
# 30537 2843.0000000         NaN
# 30538 2844.0000000         NaN
# 30539 2845.0000000         NaN
# 30540 2846.0000000         NaN
# 30541 2848.0000000         NaN
# 30542 2849.0000000         NaN
# 30543 2856.0000000         NaN
# 30544 2857.0000000         NaN
# 30545 2858.0000000         NaN
# 30546 2859.0000000         NaN
# 30547 2860.0000000         NaN
# 30548 2861.0000000         NaN
# 30549 2862.0000000         NaN
# 30550 2863.0000000         NaN
# 30551 2864.0000000         NaN
# 30552 2865.0000000         NaN
# 30553 2866.0000000         NaN
# 30554 2867.0000000         NaN
# 30555 2874.0000000         NaN
# 30556 2875.0000000         NaN
# 30557 2876.0000000         NaN
# 30558 2877.0000000         NaN
# 30559 2878.0000000         NaN
# 30560 2879.0000000         NaN
# 30561 2880.0000000         NaN
# 30562 2881.0000000         NaN
# 30563 2882.0000000         NaN
# 30564 2883.0000000         NaN
# 30565 2884.0000000         NaN
# 30566 2885.0000000         NaN
# 30567 2893.0000000         NaN
# 30568 2894.0000000         NaN
# 30569 2895.0000000         NaN
# 30570 2896.0000000         NaN
# 30571 2897.0000000         NaN
# 30572 2898.0000000         NaN
# 30573 2900.0000000         NaN
# 30574 2901.0000000         NaN
# 30575 2902.0000000         NaN
# 30576 2903.0000000         NaN
# 30577 2910.0000000         NaN
# 30578 2911.0000000         NaN
# 30579 2912.0000000         NaN
# 30580 2913.0000000         NaN
# 30581 2915.0000000         NaN
# 30582 2917.0000000         NaN
# 30583 2918.0000000         NaN
# 30584 2919.0000000         NaN
# 30585 2920.0000000         NaN
# 30586 2921.0000000         NaN
# 30587 2928.0000000         NaN
# 30588 2930.0000000         NaN
# 30589 2931.0000000         NaN
# 30590 2932.0000000         NaN
# 30591 2933.0000000         NaN
# 30592 2934.0000000         NaN
# 30593 2935.0000000         NaN
# 30594 2936.0000000         NaN
# 30595 2937.0000000         NaN
# 30596 2938.0000000         NaN
# 30597 2946.0000000         NaN
# 30598 2947.0000000         NaN
# 30599 2950.0000000         NaN
# 30600 2951.0000000         NaN
# 30601 2952.0000000         NaN
# 30602 2956.0000000         NaN
# 30603 2966.0000000         NaN
# 30604 2967.0000000         NaN
# 30605 2970.0000000         NaN
# 30606 2972.0000000         NaN
# 30607 2973.0000000         NaN
# 30608 2975.0000000         NaN
# 30609 2982.0000000         NaN
# 30610 2983.0000000         NaN
# 30611 2984.0000000         NaN
# 30612 2985.0000000         NaN
# 30613 2986.0000000         NaN
# 30614 2988.0000000         NaN
# 30615 2989.0000000         NaN
# 30616 2990.0000000         NaN
# 30617 2991.0000000         NaN
# 30618 3000.0000000         NaN
# 30619 3001.0000000         NaN
# 30620 3002.0000000         NaN
# 30621 3004.0000000         NaN
# 30622 3005.0000000         NaN
# 30623 3008.0000000         NaN
# 30624 3009.0000000         NaN
# 30625 3010.0000000         NaN
# 30626 3011.0000000         NaN
# 30627 3018.0000000         NaN
# 30628 3019.0000000         NaN
# 30629 3021.0000000         NaN
# 30630 3022.0000000         NaN
# 30631 3023.0000000         NaN
# 30632 3025.0000000         NaN
# 30633 3026.0000000         NaN
# 30634 3027.0000000         NaN
# 30635 3029.0000000         NaN
# 30636 3036.0000000         NaN
# 30637 3037.0000000         NaN
# 30638 3040.0000000         NaN
# 30639 3041.0000000         NaN
# 30640 3042.0000000         NaN
# 30641 3043.0000000         NaN
# 30642 3044.0000000         NaN
# 30643 3045.0000000         NaN
# 30644 3046.0000000         NaN
# 30645 3047.0000000         NaN
# 30646 3054.0000000         NaN
# 30647 3055.0000000         NaN
# 30648 3057.0000000         NaN
# 30649 3058.0000000         NaN
# 30650 3059.0000000         NaN
# 30651 3060.0000000         NaN
# 30652 3061.0000000         NaN
# 30653 3062.0000000         NaN
# 30654 3063.0000000         NaN
# 30655 3064.0000000         NaN
# 30656 3065.0000000         NaN
# 30657 3072.0000000         NaN
# 30658 3073.0000000         NaN
# 30659 3074.0000000         NaN
# 30660 3075.0000000         NaN
# 30661 3076.0000000         NaN
# 30662 3077.0000000         NaN
# 30663 3079.0000000         NaN
# 30664 3080.0000000         NaN
# 30665 3081.0000000         NaN
# 30666 3082.0000000         NaN
# 30667 3083.0000000         NaN
# 30668 3090.0000000         NaN
# 30669 3092.0000000         NaN
# 30670 3093.0000000         NaN
# 30671 3094.0000000         NaN
# 30672 3095.0000000         NaN
# 30673 3096.0000000         NaN
# 30674 3097.0000000         NaN
# 30675 3100.0000000         NaN
# 30676 3101.0000000         NaN
# 30677 3108.0000000         NaN
# 30678 3109.0000000         NaN
# 30679 3110.0000000         NaN
# 30680 3112.0000000         NaN
# 30681 3114.0000000         NaN
# 30682 3116.0000000         NaN
# 30683 3118.0000000         NaN
# 30684 3119.0000000         NaN
# 30685 3126.0000000         NaN
# 30686 3127.0000000         NaN
# 30687 3129.0000000         NaN
# 30688 3130.0000000         NaN
# 30689 3131.0000000         NaN
# 30690 3132.0000000         NaN
# 30691 3133.0000000         NaN
# 30692 3134.0000000         NaN
# 30693 3135.0000000         NaN
# 30694 3136.0000000         NaN
# 30695 3144.0000000         NaN
# 30696 3145.0000000         NaN
# 30697 3146.0000000         NaN
# 30698 3147.0000000         NaN
# 30699 3149.0000000         NaN
# 30700 3150.0000000         NaN
# 30701 3153.0000000         NaN
# 30702 3155.0000000         NaN
# 30703 3162.0000000         NaN
# 30704 3163.0000000         NaN
# 30705 3164.0000000         NaN
# 30706 3165.0000000         NaN
# 30707 3166.0000000         NaN
# 30708 3168.0000000         NaN
# 30709 3169.0000000         NaN
# 30710 3170.0000000         NaN
# 30711 3171.0000000         NaN
# 30712 3172.0000000         NaN
# 30713 3173.0000000         NaN
# 30714 3180.0000000         NaN
# 30715 3181.0000000         NaN
# 30716 3182.0000000         NaN
# 30717 3183.0000000         NaN
# 30718 3184.0000000         NaN
# 30719 3185.0000000         NaN
# 30720 3186.0000000         NaN
# 30721 3187.0000000         NaN
# 30722 3189.0000000         NaN
# 30723 3190.0000000         NaN
# 30724 3191.0000000         NaN
# 30725 3198.0000000         NaN
# 30726 3199.0000000         NaN
# 30727 3200.0000000         NaN
# 30728 3201.0000000         NaN
# 30729 3203.0000000         NaN
# 30730 3204.0000000         NaN
# 30731 3205.0000000         NaN
# 30732 3206.0000000         NaN
# 30733 3207.0000000         NaN
# 30734 3208.0000000         NaN
# 30735 3209.0000000         NaN
# 30736 3216.0000000         NaN
# 30737 3217.0000000         NaN
# 30738 3218.0000000         NaN
# 30739 3219.0000000         NaN
# 30740 3220.0000000         NaN
# 30741 3221.0000000         NaN
# 30742 3222.0000000         NaN
# 30743 3223.0000000         NaN
# 30744 3224.0000000         NaN
# 30745 3225.0000000         NaN
# 30746 3226.0000000         NaN
# 30747 3227.0000000         NaN
# 30748 3234.0000000         NaN
# 30749 3235.0000000         NaN
# 30750 3236.0000000         NaN
# 30751 3237.0000000         NaN
# 30752 3238.0000000         NaN
# 30753 3239.0000000         NaN
# 30754 3240.0000000         NaN
# 30755 3241.0000000         NaN
# 30756 3242.0000000         NaN
# 30757 3243.0000000         NaN
# 30758 3244.0000000         NaN
# 30759 3245.0000000         NaN
# 30760 3252.0000000         NaN
# 30761 3253.0000000         NaN
# 30762 3254.0000000         NaN
# 30763 3255.0000000         NaN
# 30764 3256.0000000         NaN
# 30765 3257.0000000         NaN
# 30766 3258.0000000         NaN
# 30767 3259.0000000         NaN
# 30768 3260.0000000         NaN
# 30769 3261.0000000         NaN
# 30770 3262.0000000         NaN
# 30771 3270.0000000         NaN
# 30772 3271.0000000         NaN
# 30773 3272.0000000         NaN
# 30774 3273.0000000         NaN
# 30775 3274.0000000         NaN
# 30776 3275.0000000         NaN
# 30777 3276.0000000         NaN
# 30778 3277.0000000         NaN
# 30779 3278.0000000         NaN
# 30780 3280.0000000         NaN
# 30781 3281.0000000         NaN
# 30782 3288.0000000         NaN
# 30783 3289.0000000         NaN
# 30784 3290.0000000         NaN
# 30785 3291.0000000         NaN
# 30786 3292.0000000         NaN
# 30787 3293.0000000         NaN
# 30788 3294.0000000         NaN
# 30789 3295.0000000         NaN
# 30790 3296.0000000         NaN
# 30791 3297.0000000         NaN
# 30792 3298.0000000         NaN
# 30793 3299.0000000         NaN
# 30794 3306.0000000         NaN
# 30795 3307.0000000         NaN
# 30796 3308.0000000         NaN
# 30797 3309.0000000         NaN
# 30798 3310.0000000         NaN
# 30799 3311.0000000         NaN
# 30800 3312.0000000         NaN
# 30801 3314.0000000         NaN
# 30802 3315.0000000         NaN
# 30803 3316.0000000         NaN
# 30804 3317.0000000         NaN
# 30805 3324.0000000         NaN
# 30806 3325.0000000         NaN
# 30807 3326.0000000         NaN
# 30808 3327.0000000         NaN
# 30809 3328.0000000         NaN
# 30810 3329.0000000         NaN
# 30811 3330.0000000         NaN
# 30812 3331.0000000         NaN
# 30813 3333.0000000         NaN
# 30814 3334.0000000         NaN
# 30815 3335.0000000         NaN
# 30816 3342.0000000         NaN
# 30817 3343.0000000         NaN
# 30818 3344.0000000         NaN
# 30819 3346.0000000         NaN
# 30820 3347.0000000         NaN
# 30821 3348.0000000         NaN
# 30822 3349.0000000         NaN
# 30823 3350.0000000         NaN
# 30824 3351.0000000         NaN
# 30825 3352.0000000         NaN
# 30826 3353.0000000         NaN
# 30827 3360.0000000         NaN
# 30828 3361.0000000         NaN
# 30829 3362.0000000         NaN
# 30830 3364.0000000         NaN
# 30831 3365.0000000         NaN
# 30832 3367.0000000         NaN
# 30833 3368.0000000         NaN
# 30834 3369.0000000         NaN
# 30835 3370.0000000         NaN
# 30836 3371.0000000         NaN
# 30837 3378.0000000         NaN
# 30838 3379.0000000         NaN
# 30839 3380.0000000         NaN
# 30840 3381.0000000         NaN
# 30841 3382.0000000         NaN
# 30842 3383.0000000         NaN
# 30843 3384.0000000         NaN
# 30844 3385.0000000         NaN
# 30845 3387.0000000         NaN
# 30846 3388.0000000         NaN
# 30847 3389.0000000         NaN
# 30848 3396.0000000         NaN
# 30849 3397.0000000         NaN
# 30850 3398.0000000         NaN
# 30851 3399.0000000         NaN
# 30852 3401.0000000         NaN
# 30853 3402.0000000         NaN
# 30854 3405.0000000         NaN
# 30855 3407.0000000         NaN
# 30856 3414.0000000         NaN
# 30857 3416.0000000         NaN
# 30858 3418.0000000         NaN
# 30859 3419.0000000         NaN
# 30860 3420.0000000         NaN
# 30861 3421.0000000         NaN
# 30862 3422.0000000         NaN
# 30863 3424.0000000         NaN
# 30864 3425.0000000         NaN
# 30865 3432.0000000         NaN
# 30866 3433.0000000         NaN
# 30867 3434.0000000         NaN
# 30868 3435.0000000         NaN
# 30869 3436.0000000         NaN
# 30870 3437.0000000         NaN
# 30871 3438.0000000         NaN
# 30872 3439.0000000         NaN
# 30873 3440.0000000         NaN
# 30874 3441.0000000         NaN
# 30875 3443.0000000         NaN
# 30876 3450.0000000         NaN
# 30877 3451.0000000         NaN
# 30878 3452.0000000         NaN
# 30879 3453.0000000         NaN
# 30880 3454.0000000         NaN
# 30881 3455.0000000         NaN
# 30882 3456.0000000         NaN
# 30883 3457.0000000         NaN
# 30884 3458.0000000         NaN
# 30885 3459.0000000         NaN
# 30886 3460.0000000         NaN
# 30887 3461.0000000         NaN
# 30888 3468.0000000         NaN
# 30889 3469.0000000         NaN
# 30890 3470.0000000         NaN
# 30891 3471.0000000         NaN
# 30892 3472.0000000         NaN
# 30893 3474.0000000         NaN
# 30894 3475.0000000         NaN
# 30895 3476.0000000         NaN
# 30896 3477.0000000         NaN
# 30897 3478.0000000         NaN
# 30898 3479.0000000         NaN
# 30899 3486.0000000         NaN
# 30900 3487.0000000         NaN
# 30901 3488.0000000         NaN
# 30902 3489.0000000         NaN
# 30903 3490.0000000         NaN
# 30904 3491.0000000         NaN
# 30905 3493.0000000         NaN
# 30906 3494.0000000         NaN
# 30907 3495.0000000         NaN
# 30908 3496.0000000         NaN
# 30909 3497.0000000         NaN
# 30910 3504.0000000         NaN
# 30911 3505.0000000         NaN
# 30912 3506.0000000         NaN
# 30913 3507.0000000         NaN
# 30914 3508.0000000         NaN
# 30915 3509.0000000         NaN
# 30916 3510.0000000         NaN
# 30917 3511.0000000         NaN
# 30918 3512.0000000         NaN
# 30919 3513.0000000         NaN
# 30920 3514.0000000         NaN
# 30921 3515.0000000         NaN
# 30922 3522.0000000         NaN
# 30923 3523.0000000         NaN
# 30924 3524.0000000         NaN
# 30925 3525.0000000         NaN
# 30926 3526.0000000         NaN
# 30927 3527.0000000         NaN
# 30928 3528.0000000         NaN
# 30929 3529.0000000         NaN
# 30930 3530.0000000         NaN
# 30931 3532.0000000         NaN
# 30932 3533.0000000         NaN
# 30933 3540.0000000         NaN
# 30934 3541.0000000         NaN
# 30935 3543.0000000         NaN
# 30936 3544.0000000         NaN
# 30937 3545.0000000         NaN
# 30938 3546.0000000         NaN
# 30939 3547.0000000         NaN
# 30940 3549.0000000         NaN
# 30941 3550.0000000         NaN
# 30942 3551.0000000         NaN
# 30943 3558.0000000         NaN
# 30944 3559.0000000         NaN
# 30945 3560.0000000         NaN
# 30946 3561.0000000         NaN
# 30947 3562.0000000         NaN
# 30948 3563.0000000         NaN
# 30949 3564.0000000         NaN
# 30950 3566.0000000         NaN
# 30951 3567.0000000         NaN
# 30952 3568.0000000         NaN
# 30953 3576.0000000         NaN
# 30954 3578.0000000         NaN
# 30955 3579.0000000         NaN
# 30956 3580.0000000         NaN
# 30957 3581.0000000         NaN
# 30958    0.0000000         NaN
# 30959    1.0000000         NaN
# 30960    2.0000000         NaN
# 30961    3.0000000         NaN
# 30962    4.0000000         NaN
# 30963    5.0000000         NaN
# 30964   13.0000000         NaN
# 30965   14.0000000         NaN
# 30966   15.0000000         NaN
# 30967   16.0000000         NaN
# 30968   17.0000000         NaN
# 30969   18.0000000         NaN
# 30970   19.0000000         NaN
# 30971   20.0000000         NaN
# 30972   21.0000000         NaN
# 30973   22.0000000         NaN
# 30974   23.0000000         NaN
# 30975   30.0000000         NaN
# 30976   31.0000000         NaN
# 30977   32.0000000         NaN
# 30978   33.0000000         NaN
# 30979   34.0000000         NaN
# 30980   35.0000000         NaN
# 30981   36.0000000         NaN
# 30982   37.0000000         NaN
# 30983   38.0000000         NaN
# 30984   39.0000000         NaN
# 30985   40.0000000         NaN
# 30986   41.0000000         NaN
# 30987   48.0000000         NaN
# 30988   49.0000000         NaN
# 30989   50.0000000         NaN
# 30990   51.0000000         NaN
# 30991   52.0000000         NaN
# 30992   53.0000000         NaN
# 30993   54.0000000         NaN
# 30994   55.0000000         NaN
# 30995   56.0000000         NaN
# 30996   57.0000000         NaN
# 30997   59.0000000         NaN
# 30998   66.0000000         NaN
# 30999   67.0000000         NaN
# 31000   69.0000000         NaN
# 31001   70.0000000         NaN
# 31002   71.0000000         NaN
# 31003   72.0000000         NaN
# 31004   73.0000000         NaN
# 31005   74.0000000         NaN
# 31006   75.0000000         NaN
# 31007   76.0000000         NaN
# 31008   77.0000000         NaN
# 31009   84.0000000         NaN
# 31010   85.0000000         NaN
# 31011   86.0000000         NaN
# 31012   87.0000000         NaN
# 31013   88.0000000         NaN
# 31014   89.0000000         NaN
# 31015   90.0000000         NaN
# 31016   91.0000000         NaN
# 31017   93.0000000         NaN
# 31018   94.0000000         NaN
# 31019   95.0000000         NaN
# 31020  102.0000000         NaN
# 31021  104.0000000         NaN
# 31022  106.0000000         NaN
# 31023  107.0000000         NaN
# 31024  108.0000000         NaN
# 31025  109.0000000         NaN
# 31026  110.0000000         NaN
# 31027  111.0000000         NaN
# 31028  112.0000000         NaN
# 31029  113.0000000         NaN
# 31030  120.0000000         NaN
# 31031  121.0000000         NaN
# 31032  123.0000000         NaN
# 31033  124.0000000         NaN
# 31034  125.0000000         NaN
# 31035  126.0000000         NaN
# 31036  127.0000000         NaN
# 31037  128.0000000         NaN
# 31038  129.0000000         NaN
# 31039  130.0000000         NaN
# 31040  131.0000000         NaN
# 31041  138.0000000         NaN
# 31042  139.0000000         NaN
# 31043  140.0000000         NaN
# 31044  141.0000000         NaN
# 31045  142.0000000         NaN
# 31046  143.0000000         NaN
# 31047  144.0000000         NaN
# 31048  145.0000000         NaN
# 31049  146.0000000         NaN
# 31050  147.0000000         NaN
# 31051  148.0000000         NaN
# 31052  149.0000000         NaN
# 31053  156.0000000         NaN
# 31054  157.0000000         NaN
# 31055  158.0000000         NaN
# 31056  159.0000000         NaN
# 31057  160.0000000         NaN
# 31058  161.0000000         NaN
# 31059  162.0000000         NaN
# 31060  163.0000000         NaN
# 31061  164.0000000         NaN
# 31062  165.0000000         NaN
# 31063  166.0000000         NaN
# 31064  167.0000000         NaN
# 31065  174.0000000         NaN
# 31066  175.0000000         NaN
# 31067  176.0000000         NaN
# 31068  177.0000000         NaN
# 31069  178.0000000         NaN
# 31070  179.0000000         NaN
# 31071  180.0000000         NaN
# 31072  181.0000000         NaN
# 31073  182.0000000         NaN
# 31074  183.0000000         NaN
# 31075  184.0000000         NaN
# 31076  185.0000000         NaN
# 31077  192.0000000         NaN
# 31078  193.0000000         NaN
# 31079  194.0000000         NaN
# 31080  195.0000000         NaN
# 31081  196.0000000         NaN
# 31082  197.0000000         NaN
# 31083  198.0000000         NaN
# 31084  199.0000000         NaN
# 31085  200.0000000         NaN
# 31086  201.0000000         NaN
# 31087  202.0000000         NaN
# 31088  203.0000000         NaN
# 31089  210.0000000         NaN
# 31090  211.0000000         NaN
# 31091  212.0000000         NaN
# 31092  213.0000000         NaN
# 31093  214.0000000         NaN
# 31094  215.0000000         NaN
# 31095  216.0000000         NaN
# 31096  217.0000000         NaN
# 31097  218.0000000         NaN
# 31098  219.0000000         NaN
# 31099  220.0000000         NaN
# 31100  221.0000000         NaN
# 31101  228.0000000         NaN
# 31102  229.0000000         NaN
# 31103  230.0000000         NaN
# 31104  231.0000000         NaN
# 31105  232.0000000         NaN
# 31106  233.0000000         NaN
# 31107  234.0000000         NaN
# 31108  235.0000000         NaN
# 31109  236.0000000         NaN
# 31110  237.0000000         NaN
# 31111  238.0000000         NaN
# 31112  239.0000000         NaN
# 31113  246.0000000         NaN
# 31114  247.0000000         NaN
# 31115  248.0000000         NaN
# 31116  249.0000000         NaN
# 31117  250.0000000         NaN
# 31118  251.0000000         NaN
# 31119  252.0000000         NaN
# 31120  253.0000000         NaN
# 31121  254.0000000         NaN
# 31122  255.0000000         NaN
# 31123  256.0000000         NaN
# 31124  257.0000000         NaN
# 31125  264.0000000         NaN
# 31126  265.0000000         NaN
# 31127  266.0000000         NaN
# 31128  267.0000000         NaN
# 31129  268.0000000         NaN
# 31130  269.0000000         NaN
# 31131  270.0000000         NaN
# 31132  271.0000000         NaN
# 31133  272.0000000         NaN
# 31134  273.0000000         NaN
# 31135  274.0000000         NaN
# 31136  275.0000000         NaN
# 31137  282.0000000         NaN
# 31138  283.0000000         NaN
# 31139  284.0000000         NaN
# 31140  285.0000000         NaN
# 31141  286.0000000         NaN
# 31142  287.0000000         NaN
# 31143  288.0000000         NaN
# 31144  289.0000000         NaN
# 31145  290.0000000         NaN
# 31146  291.0000000         NaN
# 31147  292.0000000         NaN
# 31148  293.0000000         NaN
# 31149  300.0000000         NaN
# 31150  301.0000000         NaN
# 31151  302.0000000         NaN
# 31152  303.0000000         NaN
# 31153  304.0000000         NaN
# 31154  305.0000000         NaN
# 31155  306.0000000         NaN
# 31156  307.0000000         NaN
# 31157  308.0000000         NaN
# 31158  309.0000000         NaN
# 31159  310.0000000         NaN
# 31160  311.0000000         NaN
# 31161  318.0000000         NaN
# 31162  319.0000000         NaN
# 31163  320.0000000         NaN
# 31164  321.0000000         NaN
# 31165  322.0000000         NaN
# 31166  323.0000000         NaN
# 31167  324.0000000         NaN
# 31168  325.0000000         NaN
# 31169  326.0000000         NaN
# 31170  327.0000000         NaN
# 31171  328.0000000         NaN
# 31172  329.0000000         NaN
# 31173  336.0000000         NaN
# 31174  337.0000000         NaN
# 31175  338.0000000         NaN
# 31176  339.0000000         NaN
# 31177  340.0000000         NaN
# 31178  341.0000000         NaN
# 31179  342.0000000         NaN
# 31180  343.0000000         NaN
# 31181  344.0000000         NaN
# 31182  345.0000000         NaN
# 31183  346.0000000         NaN
# 31184  347.0000000         NaN
# 31185  354.0000000         NaN
# 31186  355.0000000         NaN
# 31187  356.0000000         NaN
# 31188  357.0000000         NaN
# 31189  358.0000000         NaN
# 31190  359.0000000         NaN
# 31191  360.0000000         NaN
# 31192  361.0000000         NaN
# 31193  362.0000000         NaN
# 31194  363.0000000         NaN
# 31195  364.0000000         NaN
# 31196  365.0000000         NaN
# 31197  372.0000000         NaN
# 31198  373.0000000         NaN
# 31199  374.0000000         NaN
# 31200  375.0000000         NaN
# 31201  376.0000000         NaN
# 31202  377.0000000         NaN
# 31203  378.0000000         NaN
# 31204  379.0000000         NaN
# 31205  380.0000000         NaN
# 31206  381.0000000         NaN
# 31207  382.0000000         NaN
# 31208  383.0000000         NaN
# 31209  390.0000000         NaN
# 31210  391.0000000         NaN
# 31211  392.0000000         NaN
# 31212  393.0000000         NaN
# 31213  394.0000000         NaN
# 31214  395.0000000         NaN
# 31215  396.0000000         NaN
# 31216  397.0000000         NaN
# 31217  398.0000000         NaN
# 31218  399.0000000         NaN
# 31219  400.0000000         NaN
# 31220  401.0000000         NaN
# 31221  408.0000000         NaN
# 31222  409.0000000         NaN
# 31223  410.0000000         NaN
# 31224  411.0000000         NaN
# 31225  412.0000000         NaN
# 31226  413.0000000         NaN
# 31227  414.0000000         NaN
# 31228  415.0000000         NaN
# 31229  416.0000000         NaN
# 31230  417.0000000         NaN
# 31231  418.0000000         NaN
# 31232  419.0000000         NaN
# 31233  426.0000000         NaN
# 31234  427.0000000         NaN
# 31235  428.0000000         NaN
# 31236  429.0000000         NaN
# 31237  430.0000000         NaN
# 31238  431.0000000         NaN
# 31239  432.0000000         NaN
# 31240  433.0000000         NaN
# 31241  434.0000000         NaN
# 31242  435.0000000         NaN
# 31243  436.0000000         NaN
# 31244  437.0000000         NaN
# 31245  444.0000000         NaN
# 31246  445.0000000         NaN
# 31247  446.0000000         NaN
# 31248  447.0000000         NaN
# 31249  448.0000000         NaN
# 31250  449.0000000         NaN
# 31251  450.0000000         NaN
# 31252  451.0000000         NaN
# 31253  452.0000000         NaN
# 31254  453.0000000         NaN
# 31255  454.0000000         NaN
# 31256  455.0000000         NaN
# 31257  462.0000000         NaN
# 31258  463.0000000         NaN
# 31259  464.0000000         NaN
# 31260  465.0000000         NaN
# 31261  466.0000000         NaN
# 31262  467.0000000         NaN
# 31263  468.0000000         NaN
# 31264  469.0000000         NaN
# 31265  470.0000000         NaN
# 31266  471.0000000         NaN
# 31267  472.0000000         NaN
# 31268  473.0000000         NaN
# 31269  480.0000000         NaN
# 31270  481.0000000         NaN
# 31271  482.0000000         NaN
# 31272  483.0000000         NaN
# 31273  485.0000000         NaN
# 31274  486.0000000         NaN
# 31275  487.0000000         NaN
# 31276  488.0000000         NaN
# 31277  489.0000000         NaN
# 31278  490.0000000         NaN
# 31279  491.0000000         NaN
# 31280  498.0000000         NaN
# 31281  499.0000000         NaN
# 31282  500.0000000         NaN
# 31283  501.0000000         NaN
# 31284  502.0000000         NaN
# 31285  503.0000000         NaN
# 31286  504.0000000         NaN
# 31287  505.0000000         NaN
# 31288  506.0000000         NaN
# 31289  507.0000000         NaN
# 31290  508.0000000         NaN
# 31291  509.0000000         NaN
# 31292  516.0000000         NaN
# 31293  517.0000000         NaN
# 31294  518.0000000         NaN
# 31295  519.0000000         NaN
# 31296  520.0000000         NaN
# 31297  521.0000000         NaN
# 31298  522.0000000         NaN
# 31299  523.0000000         NaN
# 31300  524.0000000         NaN
# 31301  525.0000000         NaN
# 31302  526.0000000         NaN
# 31303  527.0000000         NaN
# 31304  535.0000000         NaN
# 31305  536.0000000         NaN
# 31306  537.0000000         NaN
# 31307  538.0000000         NaN
# 31308  539.0000000         NaN
# 31309  540.0000000         NaN
# 31310  541.0000000         NaN
# 31311  542.0000000         NaN
# 31312  543.0000000         NaN
# 31313  544.0000000         NaN
# 31314  545.0000000         NaN
# 31315  552.0000000         NaN
# 31316  553.0000000         NaN
# 31317  554.0000000         NaN
# 31318  555.0000000         NaN
# 31319  556.0000000         NaN
# 31320  557.0000000         NaN
# 31321  558.0000000         NaN
# 31322  559.0000000         NaN
# 31323  560.0000000         NaN
# 31324  561.0000000         NaN
# 31325  562.0000000         NaN
# 31326  563.0000000         NaN
# 31327  570.0000000         NaN
# 31328  571.0000000         NaN
# 31329  572.0000000         NaN
# 31330  573.0000000         NaN
# 31331  574.0000000         NaN
# 31332  575.0000000         NaN
# 31333  576.0000000         NaN
# 31334  577.0000000         NaN
# 31335  578.0000000         NaN
# 31336  579.0000000         NaN
# 31337  580.0000000         NaN
# 31338  581.0000000         NaN
# 31339  588.0000000         NaN
# 31340  589.0000000         NaN
# 31341  590.0000000         NaN
# 31342  591.0000000         NaN
# 31343  592.0000000         NaN
# 31344  593.0000000         NaN
# 31345  594.0000000         NaN
# 31346  595.0000000         NaN
# 31347  596.0000000         NaN
# 31348  597.0000000         NaN
# 31349  598.0000000         NaN
# 31350  599.0000000         NaN
# 31351  606.0000000         NaN
# 31352  607.0000000         NaN
# 31353  608.0000000         NaN
# 31354  610.0000000         NaN
# 31355  611.0000000         NaN
# 31356  612.0000000         NaN
# 31357  613.0000000         NaN
# 31358  614.0000000         NaN
# 31359  615.0000000         NaN
# 31360  616.0000000         NaN
# 31361  617.0000000         NaN
# 31362  624.0000000         NaN
# 31363  625.0000000         NaN
# 31364  626.0000000         NaN
# 31365  627.0000000         NaN
# 31366  628.0000000         NaN
# 31367  629.0000000         NaN
# 31368  630.0000000         NaN
# 31369  631.0000000         NaN
# 31370  632.0000000         NaN
# 31371  633.0000000         NaN
# 31372  634.0000000         NaN
# 31373  635.0000000         NaN
# 31374  642.0000000         NaN
# 31375  643.0000000         NaN
# 31376  644.0000000         NaN
# 31377  645.0000000         NaN
# 31378  646.0000000         NaN
# 31379  647.0000000         NaN
# 31380  648.0000000         NaN
# 31381  649.0000000         NaN
# 31382  650.0000000         NaN
# 31383  651.0000000         NaN
# 31384  652.0000000         NaN
# 31385  653.0000000         NaN
# 31386  660.0000000         NaN
# 31387  661.0000000         NaN
# 31388  662.0000000         NaN
# 31389  663.0000000         NaN
# 31390  664.0000000         NaN
# 31391  665.0000000         NaN
# 31392  666.0000000         NaN
# 31393  667.0000000         NaN
# 31394  668.0000000         NaN
# 31395  669.0000000         NaN
# 31396  670.0000000         NaN
# 31397  671.0000000         NaN
# 31398  678.0000000         NaN
# 31399  679.0000000         NaN
# 31400  680.0000000         NaN
# 31401  681.0000000         NaN
# 31402  682.0000000         NaN
# 31403  683.0000000         NaN
# 31404  684.0000000         NaN
# 31405  685.0000000         NaN
# 31406  686.0000000         NaN
# 31407  687.0000000         NaN
# 31408  688.0000000         NaN
# 31409  689.0000000         NaN
# 31410  696.0000000         NaN
# 31411  697.0000000         NaN
# 31412  698.0000000         NaN
# 31413  699.0000000         NaN
# 31414  700.0000000         NaN
# 31415  701.0000000         NaN
# 31416  702.0000000         NaN
# 31417  704.0000000         NaN
# 31418  705.0000000         NaN
# 31419  706.0000000         NaN
# 31420  707.0000000         NaN
# 31421  714.0000000         NaN
# 31422  716.0000000         NaN
# 31423  717.0000000         NaN
# 31424  718.0000000         NaN
# 31425  720.0000000         NaN
# 31426  721.0000000         NaN
# 31427  722.0000000         NaN
# 31428  723.0000000         NaN
# 31429  724.0000000         NaN
# 31430  725.0000000         NaN
# 31431  733.0000000         NaN
# 31432  734.0000000         NaN
# 31433  735.0000000         NaN
# 31434  736.0000000         NaN
# 31435  737.0000000         NaN
# 31436  738.0000000         NaN
# 31437  739.0000000         NaN
# 31438  740.0000000         NaN
# 31439  741.0000000         NaN
# 31440  743.0000000         NaN
# 31441  750.0000000         NaN
# 31442  751.0000000         NaN
# 31443  752.0000000         NaN
# 31444  753.0000000         NaN
# 31445  754.0000000         NaN
# 31446  755.0000000         NaN
# 31447  756.0000000         NaN
# 31448  757.0000000         NaN
# 31449  758.0000000         NaN
# 31450  759.0000000         NaN
# 31451  760.0000000         NaN
# 31452  761.0000000         NaN
# 31453  768.0000000         NaN
# 31454  769.0000000         NaN
# 31455  770.0000000         NaN
# 31456  771.0000000         NaN
# 31457  772.0000000         NaN
# 31458  773.0000000         NaN
# 31459  774.0000000         NaN
# 31460  775.0000000         NaN
# 31461  776.0000000         NaN
# 31462  777.0000000         NaN
# 31463  778.0000000         NaN
# 31464  779.0000000         NaN
# 31465  786.0000000         NaN
# 31466  787.0000000         NaN
# 31467  788.0000000         NaN
# 31468  789.0000000         NaN
# 31469  790.0000000         NaN
# ...
# 31807                                     Reuters
# 31808                        Kim Lachance Shandrow
# 31809                                     Reuters
# 31810                                     Reuters
# 31811                                  Carly Okyle
# 31812                                  Tim Maliyil
# 31813                                 Jacob Pramuk
# 31814                                  Justin Gray
# 31815                               Adam Lashinsky
# 31816                                   Jason Fell
# 31817                                    Tom Smith
# 31818                                     Reuters
# 31819                                     Reuters
# 31820                              Chris Beauchamp
# 31821                                    Ben Geier
# 31822                                     Reuters
# 31823                               Lisa Eadicicco
# 31824                                     Reuters
# 31825                                  Laura Entis
# 31826                                  Geoff Weiss
# 31827                                   Matt Straz
# 31828                                     Reuters
# 31829                            Alastair Bathgate
# 31830                                   Jason Fell
# 31831                               Anmar Frangoul
# 31832                                  Zach Ferres
# 31833                                   Jason Fell
# 31834                        Kim Lachance Shandrow
# 31835                           Catherine Clifford
# 31836                                  Tom Scearce
# 31837                         David Gerzof-Richard
# 31838                                  Emily Price
# 31839                                   Jason Fell
# 31840                        Kim Lachance Shandrow
# 31841                                  Emily Price
# 31842                                 Michael Gold
# 31843                                   Jason Fell
# 31844                                   Jason Fell
# 31845                                     Reuters
# 31846                                     Reuters
# 31847                                   Jason Fell
# 31848                                   Jason Fell
# 31849                                  Emily Price
# 31850                                   Jason Fell
# 31851                                  Laura Entis
# 31852                                     Reuters
# 31853                                     Reuters
# 31854                        Kim Lachance Shandrow
# 31855                                Arjun Kharpal
# 31856                                  Geoff Weiss
# 31857                        Kim Lachance Shandrow
# 31858                               Matt Rothstein
# 31859                                  Nina Zipkin
# 31860                                  Geoff Weiss
# 31861                                   Jason Fell
# 31862                                 John Ackerly
# 31863                                  Geoff Weiss
# 31864                                  Carly Okyle
# 31865                        Kim Lachance Shandrow
# 31866                                Daniel Newman
# 31867                               David Canellos
# 31868                                  Nina Zipkin
# 31869                        Kim Lachance Shandrow
# 31870                                     Reuters
# 31871                              Benjamin Snyder
# 31872                                     Reuters
# 31873                        Kim Lachance Shandrow
# 31874                                  Yoav Vilner
# 31875                                Russell Glass
# 31876                              Jason Richelson
# 31877                        Kim Lachance Shandrow
# 31878                                 Boland Jones
# 31879                                     Reuters
# 31880                                     Reuters
# 31881                                  Asha Saxena
# 31882                                  Laura Entis
# 31883                                     Reuters
# 31884                                     Reuters
# 31885                                Louis Foreman
# 31886                                  Laura Entis
# 31887                                  Geoff Weiss
# 31888                        Kim Lachance Shandrow
# 31889                               Steven Tweedie
# 31890                                  Geoff Weiss
# 31891                                    Yvonne Gu
# 31892                                     Reuters
# 31893                                  Nina Zipkin
# 31894                                     Reuters
# 31895                                   Jason Fell
# 31896                                  Emily Price
# 31897                                  Nina Zipkin
# 31898                        Kim Lachance Shandrow
# 31899                        Kim Lachance Shandrow
# 31900                                     Reuters
# 31901                        Kim Lachance Shandrow
# 31902                                  Zach Ferres
# 31903                            Heather R. Huhman
# 31904                                     Reuters
# 31905                                  Geoff Weiss
# 31906                                Sherice Jacob
# 31907                                     Reuters
# 31908                                     Reuters
# 31909                                 Ron Yekutiel
# 31910                          Philip Elmer-DeWitt
# 31911                                     Reuters
# 31912                                  Clay Dillow
# 31913                                     Reuters
# 31914                        Kim Lachance Shandrow
# 31915                        Kim Lachance Shandrow
# 31916                          Philip Elmer-DeWitt
# 31917                               Geoffrey Smith
# 31918                                     Reuters
# 31919                           Catherine Clifford
# 31920                                  Nina Zipkin
# 31921                                  Nina Zipkin
# 31922                                  Nina Zipkin
# 31923                           Catherine Clifford
# 31924                                     Reuters
# 31925                        Kim Lachance Shandrow
# 31926                        Kim Lachance Shandrow
# 31927                                  Kate Taylor
# 31928                                     Reuters
# 31929                                     Reuters
# 31930                                David Jelinek
# 31931                        Kim Lachance Shandrow
# 31932                                  Nina Zipkin
# 31933                                     Reuters
# 31934                                     Reuters
# 31935                                 Keith Tanaka
# 31936                                     Reuters
# 31937                                   Joe Putnam
# 31938                                     Reuters
# 31939                                    Ken Allen
# 31940                                  Larry Alton
# 31941                                    Eric Basu
# 31942                                  Carly Okyle
# 31943                                   Phil Wahba
# 31944                                     Reuters
# 31945                                  Carly Okyle
# 31946                                  Geoff Weiss
# 31947                                  Sujan Patel
# 31948                                     Reuters
# 31949                                     Reuters
# 31950                                      Unknown
# 31951                                  Kevin Purdy
# 31952                                  Geoff Weiss
# 31953                                   Jason Fell
# 31954                        Kim Lachance Shandrow
# 31955                                     Reuters
# 31956                                   Matt Odell
# 31957                        Tanya Benedicto Klich
# 31958                                   Jason Fell
# 31959                                  Laura Entis
# 31960                                  Geoff Weiss
# 31961                                  Kate Taylor
# 31962                               JP Mangalindan
# 31963                                   Neil Patel
# 31964                                  Laura Entis
# 31965                                  Laura Entis
# 31966                                     Reuters
# 31967                                     Reuters
# 31968                                  Geoff Weiss
# 31969                Kate Drane and Jason Domangue
# 31970                                  Nina Zipkin
# 31971                           Catherine Clifford
# 31972                                  Geoff Weiss
# 31973                          Philip Elmer-DeWitt
# 31974                                     Reuters
# 31975                                  Carly Okyle
# 31976                                 Chris Morris
# 31977                                Dan T Pickett
# 31978                                     Reuters
# 31979                                     Reuters
# 31980                                     Reuters
# 31981                                     Reuters
# 31982                                     Reuters
# 31983                        Kim Lachance Shandrow
# 31984                                     Reuters
# 31985                                  Laura Entis
# 31986                                     Reuters
# 31987                             Nicholas Carlson
# 31988                                  Rohan Ayyar
# 31989                                  Carly Okyle
# 31990                        Kim Lachance Shandrow
# 31991  Perry Marshall, Mike Rhodes, and Bryan Todd
# 31992                        Kim Lachance Shandrow
# 31993                        Kim Lachance Shandrow
# 31994                                     Reuters
# 31995                        Kim Lachance Shandrow
# 31996                                     Reuters
# 31997                                     Reuters
# 31998                                  Laura Entis
# 31999                                   Kate Mckay
# 32000                                Joe Essenfeld
# 32001                                     Reuters
# 32002                                     Reuters
# 32003                                  Dan Primack
# 32004                                     Reuters
# 32005                               Philip Damiano
# 32006                              Himanshu Sareen
# 32007                                 David Goldin
# 32008                                  Larry Alton
# 32009                        Kim Lachance Shandrow
# 32010                               JP Mangalindan
# 32011                                     Reuters
# 32012                               Jason Cipriani
# 32013                                    Eric Basu
# 32014                           Catherine Clifford
# 32015                           Catherine Clifford
# 32016                                Eric Dynowski
# 32017                        Kim Lachance Shandrow
# 32018                                  Clay Dillow
# 32019                     Christina Medici Scolaro
# 32020                                  Kate Taylor
# 32021                              David Z. Morris
# 32022                                     Reuters
# 32023                                     Reuters
# 32024                                Geoff Mcqueen
# 32025                           Entrepreneur Staff
# 32026                                  Laura Entis
# 32027                                     Reuters
# 32028                        Kim Lachance Shandrow
# 32029                                  Geoff Weiss
# 32030                                Erin Griffith
# 32031                                  Laura Entis
# 32032                                     Reuters
# 32033                                   Dave Smith
# 32034                                     Reuters
# 32035                                     Reuters
# 32036                                  Geoff Weiss
# 32037                              Michal Lev-Ram
# 32038                                  Laura Entis
# 32039                               JP Mangalindan
# 32040                        Kim Lachance Shandrow
# 32041  Perry Marshall, Mike Rhodes, and Bryan Todd
# 32042                                     Reuters
# 32043                               Lisa Eadicicco
# 32044                                 Miguel Helft
# 32045                                     Reuters
# 32046                                  Geoff Weiss
# 32047                                   Jason Fell
# 32048                                  Geoff Weiss
# 32049                                  Laura Entis
# 32050                                  Geoff Weiss
# 32051                              Laura Vanderkam
# 32052                                     Reuters
# 32053                              Gabrielle Karol
# 32054                                     Reuters
# 32055                                     Reuters
# 32056                                Erin Griffith
# 32057                        Kim Lachance Shandrow
# 32058                                  Geoff Weiss
# 32059                                     Reuters
# 32060                                     Reuters
# 32061                                     Reuters
# 32062                                  Larry Alton
# 32063                                     Reuters
# 32064                                Mike Edelhart
# 32065                                  Laura Entis
# 32066                                  Geoff Weiss
# 32067                                     Reuters
# 32068                        Kim Lachance Shandrow
# 32069                        Kim Lachance Shandrow
# 32070                                     Reuters
# 32071                                  Laura Entis
# 32072                                     Reuters
# 32073                          Laura Hale Brockway
# 32074                                John Gaudiosi
# 32075                                  Geoff Weiss
# 32076                                  Geoff Weiss
# 32077                           Catherine Clifford
# 32078                                  Geoff Weiss
# 32079                              Jillian D'Onfro
# 32080                                     Reuters
# 32081                                   Jason Fell
# 32082                                     Reuters
# 32083                               Cadie Thompson
# 32084                                  Emily Price
# 32085                                    James Eng
# 32086                                     Reuters
# 32087                                Erin Griffith
# 32088                                     Reuters
# 32089  Perry Marshall, Mike Rhodes, and Bryan Todd
# 32090                        Kim Lachance Shandrow
# 32091                               Heather Clancy
# 32092                                     Reuters
# 32093                             Robert Siciliano
# 32094                                   Jason Fell
# 32095                                  Geoff Weiss
# 32096                                  Geoff Weiss
# 32097                                   Jacob Hall
# 32098                                   Jason Fell
# 32099                                     Reuters
# 32100                                Matthew Rocco
# 32101                                John Boitnott
# 32102                                     Reuters
# 32103                                  Geoff Weiss
# 32104                                  Geoff Weiss
# 32105                                  Laura Entis
# 32106                               Benjamin Kabin
# 32107                        Kim Lachance Shandrow

# %%
# Only keep records where Domain is non blank 
df = df[df['Domain'].notna()]

# %%
df.isna().sum()
# Out:
# Unnamed: 0      1480
# Article URL     2048
# Headline           0
# Article Text       0
# Sub Domain      1480
# Domain             0
# Author             0
# dtype: int64

# %%
#Check Unique Values of Domain
df['Domain'].unique()
# Out:
# array(['Marketing', 'Finance', 'Leadership', 'Strategy', 'Technology'],
#       dtype=object)

# %%
#Unique Values of Doamin
df['Domain'].value_counts()
# Out:
# Marketing     7921
# Technology    7223
# Leadership    6563
# Strategy      5463
# Finance       4938
# Name: Domain, dtype: int64

# %%
#cleaning the text
from bs4 import BeautifulSoup
import re

def str_strip(text):
    soup = BeautifulSoup(text, "html.parser") 
    text = re.sub('\[[^]]*\]', '', soup.get_text())
    text = re.sub('\nAuthor Abstract\n', '', text)
    text = re.sub('(?=Paper Information)(?s)(.*$)', '', text)
    text = text.strip()
    text = re.sub('\n', ' ', text)
    text = re.sub('\t', ' ', text)
    text = re.sub(u'\xa0', u' ', text)
    text = re.sub('—', ' ', text)  
    pattern=r"[^a-zA-z0-9\s,.;!()&$\-']"
    text=re.sub(pattern,'',text)
    text = re.sub('/\s\s+/g', ' ', text) #remove multiple spaces
    text = re.sub('/  +/g', ' ',text)
    read_pattern1 =r'\d min read'
    read_pattern2 =r'min read'
    translation_pattern = r'This article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.'
    opinion_pattern = 'Opinions expressed by Entrepreneur contributors are their own.'
    date_pattern = r'^(?:January|February|March|April|May|June|July|August|September|October|November|December)\s+(\d+)\,\s+(\d+)\s+' 
    text=re.sub(read_pattern1,'',text)
    text=re.sub(read_pattern2,'',text)
    text=re.sub(translation_pattern,'',text)
    text=re.sub(opinion_pattern,'',text)
    text=re.sub(date_pattern,'',text)
    return text

# %%
df['Cleaned_Article']=df['Article Text'].apply(str_strip)

# %%
df['Cleaned_Headline']=df['Headline'].apply(str_strip)

# %%
df['Cleaned_Author']=df['Author'].apply(str_strip)

# %%
df['Cleaned_Author']=df['Author'].apply(str_strip)

# %%
df.head(10)
# Out:
#    Unnamed: 0                                  Article URL  \
# 0   0.0000000  https://www.entrepreneur.com/article/370874
# 1   1.0000000  https://www.entrepreneur.com/article/372254
# 2   2.0000000  https://www.entrepreneur.com/article/368356
# 3   3.0000000  https://www.entrepreneur.com/article/373825
# 4   4.0000000  https://www.entrepreneur.com/article/372679
# 5   5.0000000  https://www.entrepreneur.com/article/373603
# 6  12.0000000  https://www.entrepreneur.com/article/373832
# 7  13.0000000  https://www.entrepreneur.com/article/371210
# 8  14.0000000  https://www.entrepreneur.com/article/374003
# 9  15.0000000  https://www.entrepreneur.com/article/373995
#
#                                             Headline  \
# 0  \n\t\t\t\tIs Launching a New Brand the Right M...
# 1  \n\t\t\t\t3 Reasons Simple Isn't Always Better...
# 2  \n\t\t\t\tFrom Idea to Revenue: A Six-Step For...
# 3  \n\t\t\t\tAvoid This Common Mistake When Writi...
# 4   \n\t\t\t\tIs it Time to Say RIP to RFPs?\n\t\t\t
# 5  \n\t\t\t\t4‌ ‌Lessons‌ ‌Nonfiction‌ ‌Writers‌ ...
# 6  \n\t\t\t\tThe 5 Cs of Logo Design That Will Al...
# 7  \n\t\t\t\tThe 3 Questions That Will Help You D...
# 8  \n\t\t\t\t40 million people made use of some o...
# 9  \n\t\t\t\tHow to Sell More on Amazon Prime Day...
#
#                                         Article Text            Sub Domain  \
# 0  \n\n\n\t\t\t\t\t\t\t\tJune\n\t\t\t\t\t\t\t\t10...              Branding
# 1  \n\n\n\t\t\t\t\t\t\t\tJune\n\t\t\t\t\t\t\t\t10...              Branding
# 2  \n\n\n\t\t\t\t\t\t\t\tJune\n\t\t\t\t\t\t\t\t10...  Launching a Business
# 3  \n\n\n\t\t\t\t\t\t\t\tJune\n\t\t\t\t\t\t\t\t10...        Writing a Book
# 4  \n\n\n\t\t\t\t\t\t\t\tJune\n\t\t\t\t\t\t\t\t9,...         Entrepreneurs
# 5  \n\n\n\t\t\t\t\t\t\t\tJune\n\t\t\t\t\t\t\t\t9,...        Writing a Book
# 6  \n\n\n\t\t\t\t\t\t\t\tJune\n\t\t\t\t\t\t\t\t8,...                Design
# 7  \n\n\n\t\t\t\t\t\t\t\tJune\n\t\t\t\t\t\t\t\t8,...              Branding
# 8  \n\n\n\t\t\t\t\t\t\t\tJune\n\t\t\t\t\t\t\t\t8,...             Ecommerce
# 9  \n\n\n\t\t\t\t\t\t\t\tJune\n\t\t\t\t\t\t\t\t8,...      Amazon Prime Day
#
#       Domain                   Author  \
# 0  Marketing          Melissa Packham
# 1  Marketing            Zaheer Dodhia
# 2  Marketing        Jessica O'Connell
# 3  Marketing         R. Paulo Delgado
# 4  Marketing           Heather Ripley
# 5  Marketing         R. Paulo Delgado
# 6  Marketing            Zaheer Dodhia
# 7  Marketing                 Raj Girn
# 8  Marketing  Entrepreneur en Español
# 9  Marketing  Entrepreneur en Español
#
#                                      Cleaned_Article  \
# 0  One of the most common challenges I see client...
# 1  Lets say that, like me, youve been thinking ab...
# 2  If youre like most entrepreneurs, you may have...
# 3  I had an interesting project come across my de...
# 4  In a world where personal touch matters, why a...
# 5  I just finished reading Matthew McConaughey's ...
# 6  How do you solve a problem like a boring logo ...
# 7  What does the word branding mean to you and yo...
# 8  Digital payments in Latin America grew in a wa...
# 9  Dates for Amazon Day 2021 have already been an...
#
#                                     Cleaned_Headline          Cleaned_Author
# 0  Is Launching a New Brand the Right Move for Yo...         Melissa Packham
# 1  3 Reasons Simple Isn't Always Better When It C...           Zaheer Dodhia
# 2  From Idea to Revenue A Six-Step Formula to Lau...       Jessica O'Connell
# 3  Avoid This Common Mistake When Writing Your Fi...        R. Paulo Delgado
# 4                      Is it Time to Say RIP to RFPs          Heather Ripley
# 5  4 Lessons Nonfiction Writers Can Learn From Ma...        R. Paulo Delgado
# 6  The 5 Cs of Logo Design That Will Always Stand...           Zaheer Dodhia
# 7  The 3 Questions That Will Help You Define Your...                Raj Girn
# 8  40 million people made use of some online paym...  Entrepreneur en Espaol
# 9          How to Sell More on Amazon Prime Day 2021  Entrepreneur en Espaol

# %%
df['Article Text'][8]
# Out:
# "\n\n\n\t\t\t\t\t\t\t\tJune\n\t\t\t\t\t\t\t\t8, 2021\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t3 min read\n\t\t\t\t\t\t\t\t\t\t\t\t\t\nThis article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\n\n\nDigital payments in Latin America grew in a way that we could never imagine. Sure, the health crisis has to be taken into account, but the use of e-commerce has skyrocketed beyond any possible prediction. At least that reflects the recent study of Mercado Pago Trends of online payments in Latam one year after COVID-19 . The analysis made between April 2020 and March 2021, contemplates the use of two online payment methods: the payment processor that is used in millions of web pages and the use of the payment link, used to charge through networks social or chats. This analysis, carried out in seven countries in the region ( Argentina, Brazil, Chile, Colombia, Mexico, Peru and Uruguay ) between April 2020 and March 2021, showed that more than 40 million people made use of an online payment , \xa0 Brazil being the country with the most new users with 21 million, followed by Argentina with 8 million and Mexico with 4 million . Chile and Colombia added 3 million each, while Peru added a million new digital buyers. Likewise, more than 21 thousand entrepreneurs charged online during the last year. “During the pandemic, the online payment and collection technologies that we developed at Mercado Pago became a solution for businesses to continue operating. Sellers reached more digital customers who dared to buy online for the first time due to the ease and accessibility of our methods, ”said Yamil Kuri, Mercado Pago's online payments manager in a statement.  Image: Courtesy Mercado Pago The payment link is preferred by SMEs More than 682,000 entrepreneurs in Latin America used the payment link as their online payment method, compared to 306,000 who did so before the pandemic. In Mexico, the year-on-year increase was 61% and more than 14 thousand SMEs used this method during the pandemic, which stands out for receiving payments with a debit or credit card through a link that is sent through social networks or chats to buyers.  Image: Courtesy Mercado Pago On the other hand, 7 thousand sellers in Mexico offered their products through web pages and charged with the Mercado Pago payment processor. The figure doubled the 3,000 web marketers before the pandemic. Other Latin American countries, such as Chile and Colombia, digitized 5,000 and 4,000 businesses respectively.  Image: Courtesy Mercado Pago\n"

# %%
df['Cleaned_Article'][8]
# Out:
# "Digital payments in Latin America grew in a way that we could never imagine. Sure, the health crisis has to be taken into account, but the use of e-commerce has skyrocketed beyond any possible prediction. At least that reflects the recent study of Mercado Pago Trends of online payments in Latam one year after COVID-19 . The analysis made between April 2020 and March 2021, contemplates the use of two online payment methods the payment processor that is used in millions of web pages and the use of the payment link, used to charge through networks social or chats. This analysis, carried out in seven countries in the region ( Argentina, Brazil, Chile, Colombia, Mexico, Peru and Uruguay ) between April 2020 and March 2021, showed that more than 40 million people made use of an online payment ,   Brazil being the country with the most new users with 21 million, followed by Argentina with 8 million and Mexico with 4 million . Chile and Colombia added 3 million each, while Peru added a million new digital buyers. Likewise, more than 21 thousand entrepreneurs charged online during the last year. During the pandemic, the online payment and collection technologies that we developed at Mercado Pago became a solution for businesses to continue operating. Sellers reached more digital customers who dared to buy online for the first time due to the ease and accessibility of our methods, said Yamil Kuri, Mercado Pago's online payments manager in a statement.  Image Courtesy Mercado Pago The payment link is preferred by SMEs More than 682,000 entrepreneurs in Latin America used the payment link as their online payment method, compared to 306,000 who did so before the pandemic. In Mexico, the year-on-year increase was 61 and more than 14 thousand SMEs used this method during the pandemic, which stands out for receiving payments with a debit or credit card through a link that is sent through social networks or chats to buyers.  Image Courtesy Mercado Pago On the other hand, 7 thousand sellers in Mexico offered their products through web pages and charged with the Mercado Pago payment processor. The figure doubled the 3,000 web marketers before the pandemic. Other Latin American countries, such as Chile and Colombia, digitized 5,000 and 4,000 businesses respectively.  Image Courtesy Mercado Pago"

# %%
df['Cleaned_Author'].nunique()
# Out:
# 5868

# %%
#Lets look at authors with highest # of articles
df["Cleaned_Author"].value_counts().nlargest(30)
# Out:
# Unknown                   870
# Entrepreneur Store        699
# Catherine Clifford        527
# Kim Lachance Shandrow     515
# Reuters                   508
# Nina Zipkin               426
# Jason Fell                408
# Geoff Weiss               354
# Laura Entis               262
# John Rampton              240
# Entrepreneur en Espaol    210
# Rose Leadem               207
# John Boitnott             191
# Brian Patrick Eha         179
# Entrepreneur Staff        155
# Lydia Belanger            154
# Ivan Misner               153
# Jonathan Blum             150
# Jason Feifer              147
# Heather R. Huhman         146
# Mikal E. Belicove         146
# Jonathan Long             141
# Steve Tobak               141
# Andrew Osterland          138
# Lewis Howes               137
# Gwen Moran                136
# Thomas Smale              133
# Jim Joseph                133
# Ray Hennessey             132
# Andrew Medal              130
# Name: Cleaned_Author, dtype: int64

# %%
#List of authors who are not available or Unknown
missing_authors_names = ['Unknown','Reuters','Entrepreneur Store','Entrepreneur Staff','Entrepreneur en Espaol']
#Let's see how many records would be unavailable per author
df[df.Cleaned_Author.isin(missing_authors_names)]['Cleaned_Author'].value_counts()
# Out:
# Unknown                   870
# Entrepreneur Store        699
# Reuters                   508
# Entrepreneur en Espaol    210
# Entrepreneur Staff        155
# Name: Cleaned_Author, dtype: int64

# %%
count_missing_author = df[df.Cleaned_Author.isin(missing_authors_names)]['Cleaned_Author'].value_counts().sum()
print("\n Count of Records with Misisng Authors  needs to be dropped  :", count_missing_author)
# Out:
#  Count of Records with Misisng Authors  needs to be dropped  : 2442

# %%
# Lets remove records of these missing authors
df_clean = df[~df.Cleaned_Author.isin(missing_authors_names)]
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29666 entries, 0 to 32107
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        28358 non-null  float64
#  1   Article URL       27872 non-null  object
#  2   Headline          29666 non-null  object
#  3   Article Text      29666 non-null  object
#  4   Sub Domain        28358 non-null  object
#  5   Domain            29666 non-null  object
#  6   Author            29666 non-null  object
#  7   Cleaned_Article   29666 non-null  object
#  8   Cleaned_Headline  29666 non-null  object
#  9   Cleaned_Author    29666 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 2.5+ MB

# %%
#Lets check number of words in  Articles and store in a column
df_clean['Word_Count']=df_clean['Cleaned_Article'].apply(lambda x:len(x.split(' ')))

# %%
#Lets see how many artiicles have very few words say 50 or less
notext_df = df_clean[df_clean['Word_Count'] < 50]
notext_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 1111 to 26525
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20 non-null     float64
#  1   Article URL       35 non-null     object
#  2   Headline          35 non-null     object
#  3   Article Text      35 non-null     object
#  4   Sub Domain        20 non-null     object
#  5   Domain            35 non-null     object
#  6   Author            35 non-null     object
#  7   Cleaned_Article   35 non-null     object
#  8   Cleaned_Headline  35 non-null     object
#  9   Cleaned_Author    35 non-null     object
#  10  Word_Count        35 non-null     int64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 3.3+ KB

# %%
#Lets see how many words per articles these small ones have
notext_df.groupby('Word_Count').size()
# Out:
# Word_Count
# 1     12
# 3      1
# 7      5
# 9      1
# 10     1
# 11     1
# 13     2
# 25     1
# 26     1
# 28     1
# 30     2
# 31     2
# 35     1
# 38     1
# 45     1
# 47     2
# dtype: int64

# %%
#Only keep records with Cleaned Test length >50 words
df_clean = df_clean[df_clean['Word_Count'] >50]

# %%
#Categorize per Size of articles
df_clean['Article_Size'] = df_clean['Word_Count'].apply(lambda x: 'Small' if x <= 500 else ('Medium' if x <1000 else 'Large'))

# %%
# Count of Articles Size
df_clean.Article_Size.value_counts()
# Out:
# Medium    16576
# Large      6891
# Small      6164
# Name: Article_Size, dtype: int64

# %%
#Domainwise count
df_clean.groupby(['Domain','Article_Size']).size()
# Out:
# Domain      Article_Size
# Finance     Large           1031
#             Medium          2553
#             Small           1016
# Leadership  Large           1736
#             Medium          3889
#             Small            642
# Marketing   Large           1632
#             Medium          4572
#             Small           1263
# Strategy    Large           1578
#             Medium          3007
#             Small            620
# Technology  Large            914
#             Medium          2555
#             Small           2623
# dtype: int64

# %%
grouped_df = df_clean.groupby(['Domain','Article_Size']).size().reset_index(name="Count")
grouped_df
# Out:
#         Domain Article_Size  Count
# 0      Finance        Large   1031
# 1      Finance       Medium   2553
# 2      Finance        Small   1016
# 3   Leadership        Large   1736
# 4   Leadership       Medium   3889
# 5   Leadership        Small    642
# 6    Marketing        Large   1632
# 7    Marketing       Medium   4572
# 8    Marketing        Small   1263
# 9     Strategy        Large   1578
# 10    Strategy       Medium   3007
# 11    Strategy        Small    620
# 12  Technology        Large    914
# 13  Technology       Medium   2555
# 14  Technology        Small   2623

# %%
# Shuffle data before splitting
data_shuffled = df_clean.sample(frac=1, random_state=42) # shuffle with random_state=42 for reproducibility
data_shuffled.head()
# Out:
#         Unnamed: 0                                  Article URL  \
# 911   1458.0000000  https://www.entrepreneur.com/article/333023
# 28318 5129.0000000  https://www.entrepreneur.com/article/355070
# 20586 1152.0000000  https://www.entrepreneur.com/article/343145
# 13643 2496.0000000  https://www.entrepreneur.com/article/321218
# 4996  7914.0000000  https://www.entrepreneur.com/article/235235
#
#                                                 Headline  \
# 911    \n\t\t\t\tThe 21st Century Affluent Woman and ...
# 28318  \n\t\t\t\tSmart Home: Blossom Masters The Wate...
# 20586  \n\t\t\t\tTips to Follow When Re-Fitting Your ...
# 13643  \n\t\t\t\t9 Ways to Combat Decision Fatigue\n\...
# 4996   \n\t\t\t\tThe 3 Fundamentals for a Successful ...
#
#                                             Article Text  \
# 911    \n\n\n\t\t\t\t\t\t\t\tJune\n\t\t\t\t\t\t\t\t24...
# 28318  \n\n\n\t\t\t\t\t\t\t\tMarch\n\t\t\t\t\t\t\t\t6...
# 20586  \n\n\n\t\t\t\t\t\t\t\tAugust\n\t\t\t\t\t\t\t\t...
# 13643  \n\n\n\t\t\t\t\t\t\t\tNovember\n\t\t\t\t\t\t\t...
# 4996   \n\n\n\t\t\t\t\t\t\t\tJune\n\t\t\t\t\t\t\t\t27...
#
#                                Sub Domain      Domain          Author  \
# 911                             Marketing   Marketing  Dan S. Kennedy
# 28318                      Product Design  Technology   Tamara Clarke
# 20586                      Business Model    Strategy  Tanner Simkins
# 13643  Cultivating Emotional Intelligence  Leadership      Deep Patel
# 4996                           Rebranding   Marketing   Greg Liberman
#
#                                          Cleaned_Article  \
# 911    The following excerpt is from Dan S. Kennedys ...
# 28318  You're reading Entrepreneur Middle East, an in...
# 20586  In the midst of a global health crisis, it can...
# 13643  Making decisions, even small, seemly harmless ...
# 4996   JDate, the premier community for Jewish single...
#
#                                         Cleaned_Headline  Cleaned_Author  \
# 911    The 21st Century Affluent Woman and Her Market...  Dan S. Kennedy
# 28318          Smart Home Blossom Masters The Waterworks   Tamara Clarke
# 20586  Tips to Follow When Re-Fitting Your Business M...  Tanner Simkins
# 13643                  9 Ways to Combat Decision Fatigue      Deep Patel
# 4996         The 3 Fundamentals for a Successful Rebrand   Greg Liberman
#
#        Word_Count Article_Size
# 911          1063        Large
# 28318         167        Small
# 20586         852       Medium
# 13643        1478        Large
# 4996          769       Medium

# %%
#Split into Train and test, keep test data only for final prediction
from sklearn.model_selection import train_test_split
train, test = train_test_split(data_shuffled, test_size=0.1) #10% data saved for final test

# %%
df_clean.shape, train.shape , test.shape
# Out:
# ((29631, 12), (26667, 12), (2964, 12))

# %%
df_clean.groupby('Domain').size()
# Out:
# Domain
# Finance       4600
# Leadership    6267
# Marketing     7467
# Strategy      5205
# Technology    6092
# dtype: int64

# %%
train.groupby('Domain').size()
# Out:
# Domain
# Finance       4126
# Leadership    5641
# Marketing     6741
# Strategy      4664
# Technology    5495
# dtype: int64

# %%
test.groupby('Domain').size()
# Out:
# Domain
# Finance       474
# Leadership    626
# Marketing     726
# Strategy      541
# Technology    597
# dtype: int64

# %%
#export file and save as CSV
df_clean.to_csv("/content/drive/MyDrive/AI-ML/Data/Final_Articles_Data_25June.csv")
train.to_csv("/content/drive/MyDrive/AI-ML/Data/Final_Articles_Train_25June.csv")
test.to_csv("/content/drive/MyDrive/AI-ML/Data/Final_Articles_Test_25June.csv")

# %%
#Download the file to the local machine
#files.download("/content/drive/MyDrive/AI-ML/Data/Final_Articles_Data_25June.csv")
#files.download("/content/drive/MyDrive/AI-ML/Data/Final_Articles_Train_25June.csv")
#files.download("/content/drive/MyDrive/AI-ML/Data/Final_Articles_Test_25June.csv")
