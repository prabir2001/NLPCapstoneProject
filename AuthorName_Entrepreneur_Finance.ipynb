# %% [markdown]
# https://www.entrepreneur.com/topic/finance/
# ---

# %%
import requests
import pandas as pd
from google.colab import files
import time

# %%
from bs4 import BeautifulSoup

# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (4.2.6)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
u = []
Ent = pd.DataFrame()

common_url = 'https://www.entrepreneur.com/topic/finance/'
for i in range(1,438):
  url = (common_url + str(i))
  #print('From page:',url)
  #time.sleep(3)
  data = requests.get(url).text
  soup = BeautifulSoup(data, "lxml")
  for x in soup.find_all('div', class_="flex-1 px-6 pt-4 pb-2 flex flex-col"):
    for y in x.find_all('a',class_='block ga-click'):
      z = y.get('href')
      u.append('https://www.entrepreneur.com'+z)
      #print('https://www.entrepreneur.com'+z)
Ent['Article URL'] = u

# %%
Ent.shape
# Out:
# (1314, 1)

# %%
Ent.head()
# Out:
#                                    Article URL
# 0  https://www.entrepreneur.com/article/369935
# 1  https://www.entrepreneur.com/article/373301
# 2  https://www.entrepreneur.com/article/372691
# 3  https://www.entrepreneur.com/article/374284
# 4  https://www.entrepreneur.com/article/374285

# %%
Ent = Ent[~Ent['Article URL'].str.contains("slideshow")]
Ent = Ent[~Ent['Article URL'].str.contains("page")]
Ent = Ent[~Ent['Article URL'].str.contains("video")]
Ent = Ent[~Ent['Article URL'].str.contains("answer")]

# %%
Ent.shape
# Out:
# (1185, 1)

# %%
h = [] # To Collect Headlines
content = [] #To Collect Articles
subdomain = [] #To Collect Sub Domains
domain = [] # Domain
author = [] #To Collect Author Names

for x in Ent['Article URL']:
  url_article = x
  try:
    data_inside = requests.get(x).text
  except:
    pass

  #time.sleep(3)

  #Parse the data using Beautiful Soup
  soup_inside = BeautifulSoup(data_inside, "lxml")

#Getting the Headline
  for p in soup_inside.find_all('h1', class_='headline'):
    try:
      headline1 = p.get_text()
    except:
      pass
    h.append(headline1)

  #Getting the Content
  for q in soup_inside.find_all('div', class_='gate-check'):
    try:
      a1 = q.get_text()
    except:
      pass
    content.append(a1)

  #Getting the Sub Domain
  for sd in soup_inside.find("a", attrs={"class": "articlekicker ga-click kickertags"}):
    subdomain.append(sd)

  #Appending the Domain
  domain.append("Finance")

  #Getting the Author
  Author_Flag = bool(soup_inside.find('div', itemprop='name'))
  if Author_Flag == True:
      for r in soup_inside.find_all('div', itemprop='name'):
      #for r in soup_inside.find_all("a", attrs={"class": "authorname ga-click"}):
          try:
            au = r.get_text()
          except:
            pass     
  else:
    au = 'Unknown'
  
  author.append(au)

#Made a new column in data and added the text to that
Ent['Headline'] = h
Ent['Article Text'] = content
Ent['Sub Domain'] = subdomain
Ent['Domain'] = domain
Ent['Author'] = author

# %%
len(h)
# Out:
# 1185

# %%
len(author)
# Out:
# 1185

# %%
Ent.shape
# Out:
# (1185, 6)

# %%
Ent.head(10)
# Out:
#                                    Article URL  ...                 Author
# 0  https://www.entrepreneur.com/article/369935  ...          Rahkim Sabree
# 1  https://www.entrepreneur.com/article/373301  ...              J. Samuel
# 2  https://www.entrepreneur.com/article/372691  ...  Charles-Henry Monchau
# 3  https://www.entrepreneur.com/article/374284  ...         Michelle Jones
# 4  https://www.entrepreneur.com/article/374285  ...              Aman Jain
# 5  https://www.entrepreneur.com/article/374286  ...              Aman Jain
# 6  https://www.entrepreneur.com/article/374224  ...            Andrew Hunt
# 7  https://www.entrepreneur.com/article/374225  ...            Haroon Baig
# 8  https://www.entrepreneur.com/article/374226  ...            Brett David
# 9  https://www.entrepreneur.com/article/374134  ...          Chris Markoch
#
# [10 rows x 6 columns]

# %%
unk_auth = pd.DataFrame(Ent[Ent['Author']=='Unknown'])
unk_auth
# Out:
#                                       Article URL  ...   Author
# 441   https://www.entrepreneur.com/article/325977  ...  Unknown
# 563   https://www.entrepreneur.com/article/298461  ...  Unknown
# 903   https://www.entrepreneur.com/article/228193  ...  Unknown
# 907   https://www.entrepreneur.com/article/228103  ...  Unknown
# 913   https://www.entrepreneur.com/article/227764  ...  Unknown
# 1016   https://www.entrepreneur.com/article/52742  ...  Unknown
# 1028  https://www.entrepreneur.com/article/206616  ...  Unknown
# 1031  https://www.entrepreneur.com/article/206152  ...  Unknown
# 1035  https://www.entrepreneur.com/article/205340  ...  Unknown
# 1042  https://www.entrepreneur.com/article/204856  ...  Unknown
# 1045  https://www.entrepreneur.com/article/204506  ...  Unknown
# 1057  https://www.entrepreneur.com/article/203238  ...  Unknown
# 1065  https://www.entrepreneur.com/article/202154  ...  Unknown
# 1121  https://www.entrepreneur.com/article/176464  ...  Unknown
# 1125  https://www.entrepreneur.com/article/171296  ...  Unknown
# 1126  https://www.entrepreneur.com/article/171092  ...  Unknown
# 1132  https://www.entrepreneur.com/article/159516  ...  Unknown
# 1133  https://www.entrepreneur.com/article/166536  ...  Unknown
# 1135   https://www.entrepreneur.com/article/83806  ...  Unknown
# 1139   https://www.entrepreneur.com/article/82920  ...  Unknown
# 1141   https://www.entrepreneur.com/article/81270  ...  Unknown
# 1142   https://www.entrepreneur.com/article/81296  ...  Unknown
# 1143   https://www.entrepreneur.com/article/52832  ...  Unknown
# 1161   https://www.entrepreneur.com/article/66592  ...  Unknown
# 1171   https://www.entrepreneur.com/article/56450  ...  Unknown
# 1172   https://www.entrepreneur.com/article/56216  ...  Unknown
# 1174   https://www.entrepreneur.com/article/52970  ...  Unknown
# 1179   https://www.entrepreneur.com/article/46704  ...  Unknown
# 1182   https://www.entrepreneur.com/article/42328  ...  Unknown
# 1183   https://www.entrepreneur.com/article/41972  ...  Unknown
# 1185   https://www.entrepreneur.com/article/38448  ...  Unknown
# 1186   https://www.entrepreneur.com/article/35928  ...  Unknown
#
# [32 rows x 6 columns]

# %%
Ent['Author'].nunique()
# Out:
# 464

# %%
Ent.to_csv("Ent_Articles_Finance_withAuthor10June.csv")

#Download the file to the laptop
files.download('Ent_Articles_Finance_withAuthor10June.csv')
